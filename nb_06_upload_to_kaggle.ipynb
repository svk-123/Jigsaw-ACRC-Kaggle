# %% [markdown]
# # Jigsaw - Agile Community Rules Classification
# ### https://www.kaggle.com/competitions/jigsaw-agile-community-rules

# %%
import kagglehub
import pandas as pd
import os

base_path = "./data/"
df_train = pd.read_csv(f"{base_path}train.csv")
print(df_train.shape)
df_train.head(1)
# Out:
# (2029, 9)
#    row_id                                               body  \
# 0       0  Banks don't want you to know this! Click here ...
#
#                                                 rule   subreddit  \
# 0  No Advertising: Spam, referral links, unsolici...  Futurology
#
#                                   positive_example_1  \
# 0  If you could tell your younger self something ...
#
#                                   positive_example_2  \
# 0  hunt for lady for jack off in neighbourhood ht...
#
#                                   negative_example_1  \
# 0  Watch Golden Globe Awards 2017 Live Online in ...
#
#                                   negative_example_2  rule_violation
# 0  DOUBLE CEE x BANDS EPPS - "BIRDS"\n\nDOWNLOAD/...               0

# %%
## You may need this login if you want to upload model to kagglehub from local machine.
import os
if 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
    pass
else:
    kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
model_slug="qwen3-4b-jigsaw-acrc-merged"
variation_slug="01"

# Replace with path to directory containing model files.
LOCAL_MODEL_DIR = "./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/"

MODEL_SLUG = model_slug # Replace with model slug.

# Learn more about naming model variations at
# https://www.kaggle.com/docs/models#name-model.
VARIATION_SLUG = variation_slug # Replace with variation slug.

kagglehub.model_upload(
  handle = f"vinothkumarsekar89/{MODEL_SLUG}/transformers/{VARIATION_SLUG}",
  local_model_dir = LOCAL_MODEL_DIR,
  version_notes = 'LoRA Merged')
# Out:
# Uploading Model https://www.kaggle.com/models/vinothkumarsekar89/qwen3-4b-jigsaw-acrc-merged/transformers/01 ...
# Model 'qwen3-4b-jigsaw-acrc-merged' does not exist or access is forbidden for user 'vinothkumarsekar89'. Creating or handling Model...
# Model 'qwen3-4b-jigsaw-acrc-merged' Created.
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/merges.txt
# Uploading: 100%|████████████████████████████| 1.67M/1.67M [00:02<00:00, 580kB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/merges.txt (2MB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/tokenizer_config.json
# Uploading: 100%|███████████████████████████| 5.43k/5.43k [00:00<00:00, 6.30kB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/tokenizer_config.json (5KB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/model-00001-of-00002.safetensors
# Uploading: 100%|███████████████████████████| 4.97G/4.97G [08:44<00:00, 9.48MB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/model-00001-of-00002.safetensors (5GB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/special_tokens_map.json
# Uploading: 100%|█████████████████████████████████| 614/614 [00:00<00:00, 761B/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/special_tokens_map.json (614B)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/tokenizer.json
# Uploading: 100%|███████████████████████████| 11.4M/11.4M [00:02<00:00, 4.18MB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/tokenizer.json (11MB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/model.safetensors.index.json
# Uploading: 100%|███████████████████████████| 32.9k/32.9k [00:00<00:00, 40.9kB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/model.safetensors.index.json (32KB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/model-00002-of-00002.safetensors
# Uploading: 100%|███████████████████████████| 3.08G/3.08G [05:11<00:00, 9.87MB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/model-00002-of-00002.safetensors (3GB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/added_tokens.json
# Uploading: 100%|█████████████████████████████████| 707/707 [00:00<00:00, 865B/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/added_tokens.json (707B)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/vocab.json
# Uploading: 100%|███████████████████████████| 2.78M/2.78M [00:02<00:00, 1.28MB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/vocab.json (3MB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/chat_template.jinja
# Uploading: 100%|███████████████████████████| 4.76k/4.76k [00:00<00:00, 5.05kB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/chat_template.jinja (5KB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/config.json
# Uploading: 100%|███████████████████████████| 1.57k/1.57k [00:00<00:00, 2.01kB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/config.json (2KB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/generation_config.json
# Uploading: 100%|█████████████████████████████████| 237/237 [00:01<00:00, 143B/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r64_s10000_e_3_msl2048l_merged/generation_config.json (237B)
# Your model instance has been created.
# Files are being processed...
# See at: https://www.kaggle.com/models/vinothkumarsekar89/qwen3-4b-jigsaw-acrc-merged/transformers/01
