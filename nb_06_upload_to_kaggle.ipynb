# %% [markdown]
# # Jigsaw - Agile Community Rules Classification
# ### https://www.kaggle.com/competitions/jigsaw-agile-community-rules

# %%
import kagglehub
import pandas as pd
import os

base_path = "./data/"
df_train = pd.read_csv(f"{base_path}train.csv")
print(df_train.shape)
df_train.head(1)
# Out:
# (2029, 9)
#    row_id                                               body  \
# 0       0  Banks don't want you to know this! Click here ...
#
#                                                 rule   subreddit  \
# 0  No Advertising: Spam, referral links, unsolici...  Futurology
#
#                                   positive_example_1  \
# 0  If you could tell your younger self something ...
#
#                                   positive_example_2  \
# 0  hunt for lady for jack off in neighbourhood ht...
#
#                                   negative_example_1  \
# 0  Watch Golden Globe Awards 2017 Live Online in ...
#
#                                   negative_example_2  rule_violation
# 0  DOUBLE CEE x BANDS EPPS - "BIRDS"\n\nDOWNLOAD/...               0

# %%
## You may need this login if you want to upload model to kagglehub from local machine.
import os
if 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
    pass
else:
    kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
model_slug="qwen25-3b-instruct-jigsaw-acrc-lora"
variation_slug="16"

# Replace with path to directory containing model files.
LOCAL_MODEL_DIR = "./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap"

MODEL_SLUG = model_slug # Replace with model slug.

# Learn more about naming model variations at
# https://www.kaggle.com/docs/models#name-model.
VARIATION_SLUG = variation_slug # Replace with variation slug.

kagglehub.model_upload(
  handle = f"vinothkumarsekar89/{MODEL_SLUG}/transformers/{VARIATION_SLUG}",
  local_model_dir = LOCAL_MODEL_DIR,
  version_notes = 'Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap')
# Out:
# Uploading Model https://www.kaggle.com/models/vinothkumarsekar89/qwen25-3b-instruct-jigsaw-acrc-lora/transformers/16 ...
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/merges.txt
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|████████████████████████████| 1.67M/1.67M [00:02<00:00, 701kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/merges.txt (2MB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/tokenizer_config.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████| 4.71k/4.71k [00:00<00:00, 5.55kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/tokenizer_config.json (5KB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/adapter_model.safetensors
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|█████████████████████████████| 479M/479M [05:18<00:00, 1.50MB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/adapter_model.safetensors (457MB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/special_tokens_map.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|█████████████████████████████████| 614/614 [00:00<00:00, 730B/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/special_tokens_map.json (614B)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/tokenizer.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████| 11.4M/11.4M [00:10<00:00, 1.05MB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/tokenizer.json (11MB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/added_tokens.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|█████████████████████████████████| 605/605 [00:00<00:00, 729B/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/added_tokens.json (605B)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/vocab.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|████████████████████████████| 2.78M/2.78M [00:03<00:00, 849kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/vocab.json (3MB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/chat_template.jinja
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████| 2.51k/2.51k [00:00<00:00, 3.06kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/chat_template.jinja (2KB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/README.md
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████| 5.10k/5.10k [00:00<00:00, 5.61kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/README.md (5KB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/adapter_config.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|█████████████████████████████████| 935/935 [00:00<00:00, 937B/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r64_a64_s6087_e_2_msl2048-0swap/adapter_config.json (935B)
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Your model instance has been created.
# Files are being processed...
# See at: https://www.kaggle.com/models/vinothkumarsekar89/qwen25-3b-instruct-jigsaw-acrc-lora/transformers/16
