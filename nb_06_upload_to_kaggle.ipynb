# %% [markdown]
# # Jigsaw - Agile Community Rules Classification
# ### https://www.kaggle.com/competitions/jigsaw-agile-community-rules

# %%
import kagglehub
import pandas as pd
import os

base_path = "./data/"
df_train = pd.read_csv(f"{base_path}train.csv")
print(df_train.shape)
df_train.head(1)
# Out:
# (2029, 9)
#    row_id                                               body  \
# 0       0  Banks don't want you to know this! Click here ...
#
#                                                 rule   subreddit  \
# 0  No Advertising: Spam, referral links, unsolici...  Futurology
#
#                                   positive_example_1  \
# 0  If you could tell your younger self something ...
#
#                                   positive_example_2  \
# 0  hunt for lady for jack off in neighbourhood ht...
#
#                                   negative_example_1  \
# 0  Watch Golden Globe Awards 2017 Live Online in ...
#
#                                   negative_example_2  rule_violation
# 0  DOUBLE CEE x BANDS EPPS - "BIRDS"\n\nDOWNLOAD/...               0

# %%
## You may need this login if you want to upload model to kagglehub from local machine.
import os
if 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
    pass
else:
    kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
model_slug="qwen25-3b-instruct-jigsaw-acrc-lora"
variation_slug="09"

# Replace with path to directory containing model files.
LOCAL_MODEL_DIR = "./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k"

MODEL_SLUG = model_slug # Replace with model slug.

# Learn more about naming model variations at
# https://www.kaggle.com/docs/models#name-model.
VARIATION_SLUG = variation_slug # Replace with variation slug.

kagglehub.model_upload(
  handle = f"vinothkumarsekar89/{MODEL_SLUG}/transformers/{VARIATION_SLUG}",
  local_model_dir = LOCAL_MODEL_DIR,
  version_notes = './lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k')
# Out:
# Uploading Model https://www.kaggle.com/models/vinothkumarsekar89/qwen25-3b-instruct-jigsaw-acrc-lora/transformers/09 ...
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/merges.txt
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|████████████████████████████| 1.67M/1.67M [00:02<00:00, 756kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/merges.txt (2MB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/tokenizer_config.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████| 4.71k/4.71k [00:00<00:00, 6.11kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/tokenizer_config.json (5KB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/adapter_model.safetensors
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|█████████████████████████████| 958M/958M [02:16<00:00, 7.04MB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/adapter_model.safetensors (914MB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/special_tokens_map.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|█████████████████████████████████| 614/614 [00:00<00:00, 771B/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/special_tokens_map.json (614B)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/tokenizer.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████| 11.4M/11.4M [00:03<00:00, 3.42MB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/tokenizer.json (11MB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/added_tokens.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|█████████████████████████████████| 605/605 [00:00<00:00, 753B/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/added_tokens.json (605B)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/vocab.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████| 2.78M/2.78M [00:02<00:00, 1.23MB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/vocab.json (3MB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/chat_template.jinja
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████| 2.51k/2.51k [00:00<00:00, 3.21kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/chat_template.jinja (2KB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/README.md
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████| 5.10k/5.10k [00:00<00:00, 6.23kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/README.md (5KB)
# Starting upload for file ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/adapter_config.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Uploading: 100%|███████████████████████████████| 937/937 [00:00<00:00, 1.16kB/s]
# Upload successful: ./lora/Qwen25_3B_Instruct_unsloth_lora_fp16_r128_a128_s40394_e_2_msl2048-0-cr12-qcr12345-kdsr4k-qkdsr1234-f0p610k/adapter_config.json (937B)
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Your model instance has been created.
# Files are being processed...
# See at: https://www.kaggle.com/models/vinothkumarsekar89/qwen25-3b-instruct-jigsaw-acrc-lora/transformers/09
