# %% [markdown]
# # Rule-Filtered Vector Similarity Retrieval
#
# This notebook demonstrates a two-stage retrieval approach:
# 1. **Filter by rule**: Match the query rule to a rule category
# 2. **Retrieve top K**: Get most similar examples from that rule's examples using vector similarity

# %% [markdown]
# ## 1. Setup and Imports

# %%
# %%writefile rule_filtered_retrieval.py
"""
Rule-Filtered Vector Similarity Retrieval System with Reranking using VLLM

This system implements a three-stage retrieval:
1. Filter by matching rules first
2. Retrieve top K similar examples from filtered chunks using vector similarity
3. Rerank retrieved examples using cross-encoder for better relevance
"""

import numpy as np
import pandas as pd
import faiss
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
from typing import List, Dict, Tuple, Optional
from collections import defaultdict
import pickle
import os
from pathlib import Path
import multiprocessing as mp
mp.set_start_method('spawn', force=True)
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

from vllm import LLM
from vllm.distributed.parallel_state import destroy_model_parallel


class Qwen3RerankerVLLM:
    """Reranker using Qwen3-Reranker model with VLLM for cross-encoder scoring"""
    def __init__(self, model_name='Qwen/Qwen3-Reranker-0.6B', max_length=1024):
        # Initialize vLLM model for reranking
        number_of_gpu = torch.cuda.device_count()
        self.model = LLM(
            model=model_name,
            task="score",  # Use score task for reranking
            tensor_parallel_size=number_of_gpu,
            enable_prefix_caching=True,
            gpu_memory_utilization=0.3,  # Lower GPU memory for reranker
            max_model_len=3072,  # Reduce from default 32768 to fit in available memory
            trust_remote_code=True,
            dtype='half'  # Use float16 for memory efficiency
        )
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.max_length = max_length

    def rerank(self, query: str, documents: List[str], top_k: int = 10, batch_size: int = 32) -> List[Dict]:
        """
        Rerank documents based on query using cross-encoder scoring with VLLM

        Args:
            query: The query text
            documents: List of document texts to rerank
            top_k: Number of top results to return
            batch_size: Batch size for processing (note: VLLM handles batching internally)

        Returns:
            List of dicts with 'index' and 'score' sorted by relevance
        """
        # Get scores from VLLM - pass query as text_1 and documents as text_2
        # VLLM score() expects: score(text_1, text_2) where text_1 is query and text_2 is list of docs
        outputs = self.model.score(query, documents)
        
        # Extract scores from outputs
        scores = [o.outputs.score for o in outputs]
        
        # Create results with original indices
        results = [{'index': idx, 'score': score} for idx, score in enumerate(scores)]

        # Sort by score descending and return top_k
        results = sorted(results, key=lambda x: x['score'], reverse=True)[:top_k]

        return results
    
    def __del__(self):
        """Cleanup vLLM resources"""
        try:
            destroy_model_parallel()
        except:
            pass


class Qwen3Reranker:
    """Reranker using Qwen3-Reranker model with transformers for cross-encoder scoring"""
    def __init__(self, model_name='Qwen/Qwen3-Reranker-0.6B', max_length=1024):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModel.from_pretrained(
            model_name,
            trust_remote_code=True,
            torch_dtype=torch.float16
        )
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.model.to(self.device)
        self.model.eval()
        self.max_length = max_length

    def rerank(self, query: str, documents: List[str], top_k: int = 10, batch_size: int = 32) -> List[Dict]:
        """
        Rerank documents based on query using cross-encoder scoring

        Args:
            query: The query text
            documents: List of document texts to rerank
            top_k: Number of top results to return
            batch_size: Batch size for processing

        Returns:
            List of dicts with 'index' and 'score' sorted by relevance
        """
        all_scores = []

        # Process in batches
        for i in range(0, len(documents), batch_size):
            batch_docs = documents[i:i+batch_size]

            # Create query-document pairs
            pairs = [[query, doc] for doc in batch_docs]

            # Tokenize pairs
            encoded = self.tokenizer(
                pairs,
                padding=True,
                truncation=True,
                return_tensors='pt',
                max_length=self.max_length
            )
            encoded = {k: v.to(self.device) for k, v in encoded.items()}

            with torch.no_grad():
                outputs = self.model(**encoded, return_dict=True)
                
                # For Qwen3-Reranker, use last hidden state to compute relevance scores
                # Get [CLS] token embeddings (first token) and project to scores
                last_hidden_state = outputs.last_hidden_state
                cls_embeddings = last_hidden_state[:, 0, :]  # Shape: [batch_size, hidden_dim]
                
                # Simple scoring: use mean of CLS embedding as relevance score
                # You can also train a linear layer on top if you have labeled data
                scores = cls_embeddings.mean(dim=-1).cpu().float().numpy()

            all_scores.extend(scores.tolist() if isinstance(scores, np.ndarray) else [scores])

        # Create results with original indices
        results = [{'index': idx, 'score': score} for idx, score in enumerate(all_scores)]

        # Sort by score descending and return top_k
        results = sorted(results, key=lambda x: x['score'], reverse=True)[:top_k]

        return results


class FastEmbedder:
    """Lightweight embedder using Qwen3-Embedding model with vLLM for faster GPU inference"""
    def __init__(self, model_name='Qwen/Qwen3-Embedding-0.6B', output_dim=512):
        # Initialize vLLM model with multi-GPU support
        number_of_gpu = torch.cuda.device_count()
        self.model = LLM(
            model=model_name,
            task="embed",
            tensor_parallel_size=number_of_gpu,
            enable_prefix_caching=True,
            gpu_memory_utilization=0.3,
            max_model_len=3072,  # Reduce from default 32768 to fit in available memory
            trust_remote_code=True,
            dtype='half'  # Use float16 for memory efficiency
        )
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.output_dim = output_dim
        self.max_length = 1024

    def get_detailed_instruct(self, task_description: str, query: str) -> str:
        """Format instruction with query"""
        return f'Instruct: {task_description}\nQuery: {query}'

    def encode(self, texts, batch_size=32, convert_to_numpy=True, instruction=None):
        """Encode texts to embeddings with optional instruction"""
        if instruction:
            texts = [self.get_detailed_instruct(instruction, text) for text in texts]

        # Use vLLM embed method
        outputs = self.model.embed(texts)
        
        # Extract embeddings from outputs - VLLM returns list of EmbeddingRequestOutput
        embeddings_list = [o.outputs.embedding for o in outputs]
        
        # Convert to tensor
        embeddings = torch.tensor(embeddings_list, dtype=torch.float32)

        # Apply output dimension reduction if needed
        if self.output_dim and self.output_dim < embeddings.shape[1]:
            embeddings = embeddings[:, :self.output_dim]
            embeddings = F.normalize(embeddings, p=2, dim=1)

        if convert_to_numpy:
            return embeddings.cpu().numpy().astype(np.float32)
        return embeddings
    
    def __del__(self):
        """Cleanup vLLM resources"""
        try:
            destroy_model_parallel()
        except:
            pass


class RuleFilteredRetriever:
    """
    Three-stage retrieval system:
    1. Filter by rule category
    2. Retrieve top K similar examples from filtered set
    3. Rerank using cross-encoder
    """

    def __init__(self, embedder: FastEmbedder, reranker: Optional[Qwen3Reranker] = None, use_gpu: bool = True):
        self.embedder = embedder
        self.reranker = reranker
        self.use_gpu = use_gpu and faiss.get_num_gpus() > 0

        # Store rule categories and their indices
        self.rule_to_indices = defaultdict(list)
        self.rule_to_faiss_index = {}
        self.rule_to_data = {}

        # Global storage
        self.all_data = None
        self.all_vectors = None

    def build_index(self, df: pd.DataFrame, rule_col: str = 'rule',
                   comment_col: str = 'test_comment',
                   value_col: str = 'value',
                   instruction: Optional[str] = None):
        """
        Build FAISS indices per rule category
        Uses ONLY comment embeddings for similarity search within each rule

        Args:
            df: DataFrame with rules, comments, and values
            rule_col: Column name for rules
            comment_col: Column name for comments
            value_col: Column name for target values
            instruction: Optional instruction for embeddings
        """
        print(f"Building rule-filtered index from {len(df)} examples...")
        print("Strategy: Filter by rule FIRST, then search by COMMENT similarity only")

        # Store data
        df = df.copy()
        self.all_data = df

        # Group by rule
        rule_groups = df.groupby(rule_col)
        print(f"Found {len(rule_groups)} unique rules")

        # Encode ONLY comments for similarity search (not rule+comment combined)
        print("Encoding comments only (not combined with rules)...")
        all_vectors = self.embedder.encode(
            df[comment_col].tolist(),
            instruction=instruction
        )
        faiss.normalize_L2(all_vectors)
        self.all_vectors = all_vectors

        # Build separate FAISS index for each rule
        print("Building per-rule FAISS indices...")
        for rule, group_df in rule_groups:
            indices = group_df.index.tolist()
            rule_vectors = all_vectors[indices]

            # Store mapping
            self.rule_to_indices[rule] = indices
            self.rule_to_data[rule] = group_df

            # Build FAISS index for this rule using ONLY comment vectors
            dimension = rule_vectors.shape[1]
            index = faiss.IndexFlatIP(dimension)

            if self.use_gpu:
                res = faiss.StandardGpuResources()
                index = faiss.index_cpu_to_gpu(res, 0, index)

            index.add(rule_vectors)
            self.rule_to_faiss_index[rule] = index

            print(f"  Rule '{rule[:50]}...' : {len(indices)} examples")

        print(f"\nIndex building complete!")
        print(f"Total rules: {len(self.rule_to_faiss_index)}")
        print(f"Total examples: {len(df)}")

    def retrieve(self, query_rule: str, query_comment: str,
                top_k: int = 10,
                retrieval_k: int = 100,
                instruction: Optional[str] = None,
                fallback_to_similar_rules: bool = True,
                use_reranking: bool = True) -> Dict:
        """
        Three-stage retrieval:
        1. Filter by rule (exact or similar)
        2. Retrieve top retrieval_k by comment similarity
        3. Rerank to get final top_k (if reranker available)

        Args:
            query_rule: The rule to match
            query_comment: The comment to find similar examples for
            top_k: Final number of examples after reranking (default: 10)
            retrieval_k: Number of examples to retrieve before reranking (default: 100)
            instruction: Optional instruction for encoding
            fallback_to_similar_rules: If exact rule not found, use rule similarity
            use_reranking: Whether to use reranker (if available)

        Returns:
            Dict with retrieved examples and metadata including both FAISS and rerank scores
        """
        # STAGE 1: Filter by rule first
        if query_rule in self.rule_to_faiss_index:
            matched_rule = query_rule
            rule_match_type = "exact"
        elif fallback_to_similar_rules:
            matched_rule, rule_match_type = self._find_similar_rule(query_rule, instruction)
        else:
            return {
                'success': False,
                'error': f'Rule not found: {query_rule}',
                'matched_rule': None,
                'examples': []
            }

        # STAGE 2: Encode ONLY the comment for similarity search
        query_vector = self.embedder.encode(
            [query_comment],
            instruction=instruction
        )
        faiss.normalize_L2(query_vector)

        # Get FAISS index for matched rule
        rule_index = self.rule_to_faiss_index[matched_rule]
        rule_data = self.rule_to_data[matched_rule]

        # Retrieve top retrieval_k candidates
        similarities, indices = rule_index.search(query_vector, min(retrieval_k, len(rule_data)))

        # Get actual dataframe indices
        actual_indices = [self.rule_to_indices[matched_rule][i] for i in indices[0]]
        retrieved_examples = self.all_data.iloc[actual_indices]

        # STAGE 3: Rerank if reranker is available and enabled
        if use_reranking and self.reranker is not None and len(retrieved_examples) > 0:
            # Get document texts for reranking
            documents = retrieved_examples['body'].tolist()
            
            # Rerank using cross-encoder
            rerank_results = self.reranker.rerank(
                query=query_comment,
                documents=documents,
                top_k=min(top_k, len(documents))
            )
            
            # Reorder examples based on reranking scores
            reranked_indices = [r['index'] for r in rerank_results]
            reranked_scores = [r['score'] for r in rerank_results]
            
            # Get corresponding FAISS scores for the reranked examples
            faiss_scores_reranked = [similarities[0][idx] for idx in reranked_indices]
            
            # Get reranked examples
            final_examples = retrieved_examples.iloc[reranked_indices].reset_index(drop=True)
            
            return {
                'success': True,
                'matched_rule': matched_rule,
                'rule_match_type': rule_match_type,
                'query_rule': query_rule,
                'query_comment': query_comment,
                'faiss_scores': faiss_scores_reranked,
                'rerank_scores': reranked_scores,
                'examples': final_examples.to_dict('records'),
                'num_examples_in_rule': len(rule_data),
                'reranked': True,
                'retrieval_k': retrieval_k,
                'final_k': len(final_examples)
            }
        else:
            # No reranking - return top_k from initial retrieval
            final_examples = retrieved_examples.iloc[:top_k]
            final_scores = similarities[0][:top_k].tolist()
            
            return {
                'success': True,
                'matched_rule': matched_rule,
                'rule_match_type': rule_match_type,
                'query_rule': query_rule,
                'query_comment': query_comment,
                'faiss_scores': final_scores,
                'rerank_scores': None,
                'examples': final_examples.to_dict('records'),
                'num_examples_in_rule': len(rule_data),
                'reranked': False,
                'retrieval_k': retrieval_k,
                'final_k': len(final_examples)
            }

    def _find_similar_rule(self, query_rule: str, instruction: Optional[str] = None) -> Tuple[str, str]:
        """Find the most similar rule to query_rule using embedding similarity"""
        # Encode query rule
        query_rule_vector = self.embedder.encode(
            [f"rule: {query_rule}"],
            instruction=instruction
        )
        faiss.normalize_L2(query_rule_vector)

        # Encode all unique rules
        unique_rules = list(self.rule_to_faiss_index.keys())
        rule_vectors = self.embedder.encode(
            [f"rule: {r}" for r in unique_rules],
            instruction=instruction
        )
        faiss.normalize_L2(rule_vectors)

        # Find most similar
        similarities = np.dot(query_rule_vector, rule_vectors.T)[0]
        best_idx = np.argmax(similarities)
        best_rule = unique_rules[best_idx]

        return best_rule, f"similar (similarity: {similarities[best_idx]:.3f})"

    def batch_retrieve(self, df_query: pd.DataFrame,
                      rule_col: str = 'rule',
                      comment_col: str = 'test_comment',
                      top_k: int = 10,
                      retrieval_k: int = 100,
                      instruction: Optional[str] = None,
                      use_reranking: bool = True,
                      faiss_weight: float = 0.5,
                      rerank_weight: float = 0.5) -> pd.DataFrame:
        """
        Batch retrieval for multiple queries with weighted score combination

        Args:
            df_query: DataFrame with query rules and comments
            rule_col: Column name for rules
            comment_col: Column name for comments
            top_k: Final number of examples after reranking (default: 10)
            retrieval_k: Number to retrieve before reranking (default: 100)
            instruction: Optional instruction for encoding
            use_reranking: Whether to use reranker
            faiss_weight: Weight for FAISS scores (default: 0.5)
            rerank_weight: Weight for rerank scores (default: 0.5)

        Returns:
            DataFrame with predictions
        """
        results = []

        for idx, row in df_query.iterrows():
            query_rule = row[rule_col]
            query_comment = row[comment_col]

            # Retrieve and rerank examples
            retrieval_result = self.retrieve(
                query_rule=query_rule,
                query_comment=query_comment,
                top_k=top_k,
                retrieval_k=retrieval_k,
                instruction=instruction,
                use_reranking=use_reranking
            )

            if retrieval_result['success']:
                examples = retrieval_result['examples']
                values = [ex['value'] for ex in examples]

                # Calculate weighted score combination
                if retrieval_result['reranked'] and retrieval_result['rerank_scores'] is not None:
                    # Weighted combination: (faiss_weight * faiss_score + rerank_weight * rerank_score) * value
                    faiss_scores = retrieval_result['faiss_scores']
                    rerank_scores = retrieval_result['rerank_scores']
                    
                    # Normalize scores to similar ranges if needed
                    # FAISS scores are cosine similarities (0-1 range typically)
                    # Rerank scores may need normalization depending on model output
                    
                    weighted_sum = sum(
                        (faiss_weight * faiss_score + rerank_weight * rerank_score) * val
                        for faiss_score, rerank_score, val in zip(faiss_scores, rerank_scores, values)
                    )
                else:
                    # No reranking - use only FAISS scores
                    faiss_scores = retrieval_result['faiss_scores']
                    weighted_sum = sum(score * val for score, val in zip(faiss_scores, values))

                # Decision based on sign of weighted sum
                decision = 1 if weighted_sum >= 0 else 0
                avg_violation = weighted_sum  # Store weighted sum for inspection

                results.append({
                    'row_id': idx,
                    'rule_violation': avg_violation,
                    'decision': decision,
                    'matched_rule': retrieval_result['matched_rule'],
                    'rule_match_type': retrieval_result['rule_match_type'],
                    'num_retrieved': len(examples),
                    'reranked': retrieval_result.get('reranked', False)
                })
            else:
                # Fallback: return neutral prediction
                results.append({
                    'row_id': idx,
                    'rule_violation': 0.5,
                    'decision': 0,
                    'matched_rule': None,
                    'rule_match_type': 'not_found',
                    'num_retrieved': 0,
                    'reranked': False
                })

        return pd.DataFrame(results)

    def save_index(self, save_dir: str):
        """
        Save the retriever indices and data to disk

        Args:
            save_dir: Directory to save the index files
        """
        save_path = Path(save_dir)
        save_path.mkdir(parents=True, exist_ok=True)

        print(f"Saving index to {save_dir}...")

        # Save FAISS indices (convert GPU to CPU first if needed)
        faiss_dir = save_path / "faiss_indices"
        faiss_dir.mkdir(exist_ok=True)

        for rule, index in self.rule_to_faiss_index.items():
            # Convert to CPU index if it's a GPU index
            if self.use_gpu:
                cpu_index = faiss.index_gpu_to_cpu(index)
            else:
                cpu_index = index

            # Create safe filename from rule
            safe_filename = f"index_{hash(rule) % 10**8}.faiss"
            faiss.write_index(cpu_index, str(faiss_dir / safe_filename))

        # Save metadata (rule mappings)
        metadata = {
            'rule_to_indices': dict(self.rule_to_indices),
            'rule_to_filename': {rule: f"index_{hash(rule) % 10**8}.faiss"
                                 for rule in self.rule_to_faiss_index.keys()},
            'use_gpu': self.use_gpu
        }

        with open(save_path / "metadata.pkl", 'wb') as f:
            pickle.dump(metadata, f)

        # Save training data
        if self.all_data is not None:
            self.all_data.to_parquet(save_path / "training_data.parquet", index=True)

        # Save embeddings
        if self.all_vectors is not None:
            np.save(save_path / "embeddings.npy", self.all_vectors)

        # Save rule_to_data mapping
        rule_data_mapping = {rule: df.index.tolist() for rule, df in self.rule_to_data.items()}
        with open(save_path / "rule_data_mapping.pkl", 'wb') as f:
            pickle.dump(rule_data_mapping, f)

        print(f"✓ Index saved successfully!")
        print(f"  - {len(self.rule_to_faiss_index)} FAISS indices")
        print(f"  - {len(self.all_data)} training examples")
        print(f"  - Embeddings shape: {self.all_vectors.shape}")

    def load_index(self, load_dir: str):
        """
        Load a previously saved index from disk

        Args:
            load_dir: Directory containing the saved index files
        """
        load_path = Path(load_dir)

        if not load_path.exists():
            raise FileNotFoundError(f"Index directory not found: {load_dir}")

        print(f"Loading index from {load_dir}...")

        # Load metadata
        with open(load_path / "metadata.pkl", 'rb') as f:
            metadata = pickle.load(f)

        self.rule_to_indices = defaultdict(list, metadata['rule_to_indices'])
        rule_to_filename = metadata['rule_to_filename']
        saved_use_gpu = metadata['use_gpu']

        # Load training data
        if (load_path / "training_data.parquet").exists():
            self.all_data = pd.read_parquet(load_path / "training_data.parquet")

        # Load embeddings
        if (load_path / "embeddings.npy").exists():
            self.all_vectors = np.load(load_path / "embeddings.npy")

        # Load rule_to_data mapping
        with open(load_path / "rule_data_mapping.pkl", 'rb') as f:
            rule_data_mapping = pickle.load(f)

        # Reconstruct rule_to_data from mapping
        self.rule_to_data = {}
        for rule, indices in rule_data_mapping.items():
            self.rule_to_data[rule] = self.all_data.loc[indices]

        # Load FAISS indices
        faiss_dir = load_path / "faiss_indices"
        self.rule_to_faiss_index = {}

        for rule, filename in rule_to_filename.items():
            # Load CPU index
            cpu_index = faiss.read_index(str(faiss_dir / filename))

            # Convert to GPU if requested and available
            if self.use_gpu and faiss.get_num_gpus() > 0:
                res = faiss.StandardGpuResources()
                gpu_index = faiss.index_cpu_to_gpu(res, 0, cpu_index)
                self.rule_to_faiss_index[rule] = gpu_index
            else:
                self.rule_to_faiss_index[rule] = cpu_index

        print(f"✓ Index loaded successfully!")
        print(f"  - {len(self.rule_to_faiss_index)} FAISS indices")
        print(f"  - {len(self.all_data)} training examples")
        print(f"  - Embeddings shape: {self.all_vectors.shape}")
        print(f"  - Using GPU: {self.use_gpu}")
# Out:
# Overwriting rule_filtered_retrieval.py

# %% [markdown]
# ## 2. Load Training/Test Data & format it

# %%
# %%writefile load_train_test_data.py

# Load training data
import pandas as pd
import numpy as np
from cleantext import clean

def cleaner(text):
    """Clean text by removing URLs, emails, phone numbers"""
    return clean(
        text,
        fix_unicode=True,
        to_ascii=True,
        lower=False,
        no_line_breaks=False,
        no_urls=True,
        no_emails=True,
        no_phone_numbers=True,
        no_numbers=False,
        no_digits=False,
        no_currency_symbols=False,
        no_punct=False,
        replace_with_url="<URL>",
        replace_with_email="<EMAIL>",
        replace_with_phone_number="<PHONE>",
        lang="en",
    )

def build_prompt(row):
    """Build prompt with subreddit context"""
    return f"""r/{row["subreddit"]}\nComment: {row["body"]}"""

base_path = "./data/"
df_train = pd.read_csv(f"{base_path}train.csv")
df_train['value']=df_train['rule_violation'].copy()
df_train['value'] = df_train['value'].replace(0, -1)
df_train = df_train.sample(frac=1).reset_index(drop=True)

print(f"Total training examples: {len(df_train):,}")
print(f"Unique rules: {df_train['rule'].nunique():,}")
print(f"\nColumns: {df_train.columns.tolist()}")

# Show rule distribution
rule_counts = df_train['rule'].value_counts()
print(f"\nRule distribution statistics:")
print(f"  Mean examples per rule: {rule_counts.mean():.1f}")
print(f"  Median examples per rule: {rule_counts.median():.1f}")
print(f"  Min examples per rule: {rule_counts.min()}")
print(f"  Max examples per rule: {rule_counts.max()}")

df_train.head()
print(df_train["value"].unique())

### format data
# Step 1: Keep only the main row
df_main = df_train[['rule', 'subreddit', 'body', 'rule_violation']].copy()

# Step 2: Positive examples
df_pos1 = df_train[['rule', 'subreddit', 'positive_example_1']].copy()
df_pos1['rule_violation'] = 1
df_pos1.rename(columns={'positive_example_1': 'body'}, inplace=True)

df_pos2 = df_train[['rule', 'subreddit', 'positive_example_2']].copy()
df_pos2['rule_violation'] = 1
df_pos2.rename(columns={'positive_example_2': 'body'}, inplace=True)

# Step 3: Negative examples
df_neg1 = df_train[['rule', 'subreddit', 'negative_example_1']].copy()
df_neg1['rule_violation'] = 0
df_neg1.rename(columns={'negative_example_1': 'body'}, inplace=True)

df_neg2 = df_train[['rule', 'subreddit', 'negative_example_2']].copy()
df_neg2['rule_violation'] = 0
df_neg2.rename(columns={'negative_example_2': 'body'}, inplace=True)

# Step 4: Concatenate all
df_train_vs = pd.concat([df_main, df_pos1, df_pos2, df_neg1, df_neg2], ignore_index=True)
df_train_vs["value"]=df_train_vs["rule_violation"].copy()

# Step 5: Convert rule_violation to binary value
df_train_vs['value'] = df_train_vs['value'].replace(0, -1)

print(df_train_vs.shape)
print(df_train_vs["value"].unique())
# Show rule distribution
rule_counts = df_train_vs['rule'].value_counts()
print(f"\nRule distribution statistics:")
print(f"  Mean examples per rule: {rule_counts.mean():.1f}")
print(f"  Median examples per rule: {rule_counts.median():.1f}")
print(f"  Min examples per rule: {rule_counts.min()}")
print(f"  Max examples per rule: {rule_counts.max()}")

df_train_vs.head()

#load test data - sample 60% for training augmentation
df_test = pd.read_csv(f"{base_path}test.csv")
df_test_sample = df_test.sample(frac=0.7, random_state=21).reset_index(drop=True)

# Initialize new columns
df_test_sample['rule_violation'] = 100
df_test_sample['value'] = 100

# Shuffle the dataframe
df_test_sample = df_test_sample.sample(frac=1).reset_index(drop=True)

# Show rule distribution
rule_counts = df_test_sample['rule'].value_counts()
print(f"\nTest sample rule distribution statistics:")
print(f"  Mean examples per rule: {rule_counts.mean():.1f}")
print(f"  Median examples per rule: {rule_counts.median():.1f}")
print(f"  Min examples per rule: {rule_counts.min()}")
print(f"  Max examples per rule: {rule_counts.max()}")

print(df_test_sample["value"].unique())
print(df_test_sample.shape)
df_test_sample.head(2)

# Step 1: Keep only the main row
# Skip

# Step 2: Positive examples
df_pos1 = df_test_sample[['rule', 'subreddit', 'positive_example_1']].copy()
df_pos1['rule_violation'] = 1
df_pos1.rename(columns={'positive_example_1': 'body'}, inplace=True)

df_pos2 = df_test_sample[['rule', 'subreddit', 'positive_example_2']].copy()
df_pos2['rule_violation'] = 1
df_pos2.rename(columns={'positive_example_2': 'body'}, inplace=True)

# Step 3: Negative examples
df_neg1 = df_test_sample[['rule', 'subreddit', 'negative_example_1']].copy()
df_neg1['rule_violation'] = 0
df_neg1.rename(columns={'negative_example_1': 'body'}, inplace=True)

df_neg2 = df_test_sample[['rule', 'subreddit', 'negative_example_2']].copy()
df_neg2['rule_violation'] = 0
df_neg2.rename(columns={'negative_example_2': 'body'}, inplace=True)

# Step 4: Concatenate all
df_test_vs = pd.concat([df_pos1, df_pos2, df_neg1, df_neg2], ignore_index=True)
df_test_vs["value"]=df_test_vs["rule_violation"].copy()

# Step 5: Convert rule_violation to binary value
df_test_vs['value'] = df_test_vs['value'].replace(0, -1)
df_test_vs = df_test_vs[df_test_vs['value'].isin([1, -1])]

print(df_test_vs.shape)
print(df_test_vs["value"].unique())
print(df_test_vs["value"].value_counts())

# Show rule distribution
rule_counts = df_test_vs['rule'].value_counts()
print(f"\nRule distribution statistics:")
print(f"  Mean examples per rule: {rule_counts.mean():.1f}")
print(f"  Median examples per rule: {rule_counts.median():.1f}")
print(f"  Min examples per rule: {rule_counts.min()}")
print(f"  Max examples per rule: {rule_counts.max()}")

df_test_vs.head()

#combine train/test data - add test examples to training set
df_train_vs = pd.concat([df_test_vs, df_train_vs], ignore_index=True)
print(f"\nCombined train shape (train + 60% test): {df_train_vs.shape}")

# Apply prompt formatting with subreddit context
print("Applying prompt formatting with subreddit context...")
df_train_vs['prompt'] = df_train_vs.apply(build_prompt, axis=1)

# Apply text cleaning
print("Cleaning text...")
df_train_vs['prompt'] = df_train_vs['prompt'].apply(cleaner)

# Update body column with cleaned prompt
df_train_vs['body'] = df_train_vs['prompt']

# Save
df_train_vs[['rule', 'body', 'rule_violation', 'value']].to_csv("df_train_vs.csv", index=False)
print(f"Final shape: {df_train_vs.shape}")
print("df train vs saved success.!")
# Out:
# Overwriting load_train_test_data.py

# %%
# %%writefile run_similarity_search.py
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
from rule_filtered_retrieval import FastEmbedder, Qwen3RerankerVLLM, RuleFilteredRetriever
from sklearn.metrics import f1_score, classification_report
from cleantext import clean
import gc
import torch

def cleaner(text):
    """Clean text by removing URLs, emails, phone numbers"""
    return clean(
        text,
        fix_unicode=True,
        to_ascii=True,
        lower=False,
        no_line_breaks=False,
        no_urls=True,
        no_emails=True,
        no_phone_numbers=True,
        no_numbers=False,
        no_digits=False,
        no_currency_symbols=False,
        no_punct=False,
        replace_with_url="<URL>",
        replace_with_email="<EMAIL>",
        replace_with_phone_number="<PHONE>",
        lang="en",
    )

def build_prompt(row):
    """Build prompt with subreddit context"""
    return f"""r/{row["subreddit"]}\nComment: {row["body"]}"""

def clear_gpu_memory():
    """Clear GPU cache and run garbage collection"""
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.synchronize()
        
        # Print memory stats
        for i in range(torch.cuda.device_count()):
            allocated = torch.cuda.memory_allocated(i) / 1024**3
            reserved = torch.cuda.memory_reserved(i) / 1024**3
            total = torch.cuda.get_device_properties(i).total_memory / 1024**3
            free = total - allocated
            print(f"GPU {i}: {free:.2f} GB free / {total:.2f} GB total (allocated: {allocated:.2f} GB)")

if __name__ == '__main__':
        
    ###load here---------------------------
    df_train_vs=pd.read_csv("df_train_vs.csv") # index-train data
    df_test = pd.read_csv("./data/train.csv") # test data

    # Apply same preprocessing to test data
    print("Preprocessing test data...")
    df_test['prompt'] = df_test.apply(build_prompt, axis=1)
    df_test['prompt'] = df_test['prompt'].apply(cleaner)
    df_test['body'] = df_test['prompt']

    RETRIEVAL_K = 100  # Retrieve top 100 candidates
    RERANK_TOP_K = 4  # Rerank to get top 10
    USE_VLLM_RERANKER = True  # Set to True to use VLLM-based reranker
    ###------------------------------------

    print(df_train_vs.shape)

    # Initialize embedder with VLLM
    print("Loading Qwen3-Embedding model with VLLM...")
    embedder = FastEmbedder(
        model_name='Qwen/Qwen3-Embedding-0.6B',
        output_dim=1024  # Can experiment with 512, 1024, or full dimension
    )
    print(f"Embedder initialized on device: {embedder.device}")
    

    # Initialize reranker with VLLM
    if USE_VLLM_RERANKER:
        print("\nLoading Qwen3-Reranker model with VLLM...")
        reranker = Qwen3RerankerVLLM(
            model_name='Qwen/Qwen3-Reranker-0.6B',
            max_length=1024
        )
        print(f"Reranker (VLLM) initialized on device: {reranker.device}")
    else:
        print("Reranker disabled for this run")
        reranker = None


    # Initialize retriever and build index
    print("Initializing retriever with reranker...")
    retriever = RuleFilteredRetriever(embedder, reranker=reranker, use_gpu=True)

    # Define instruction for better retrieval
    instruction = "Given a rule and comment, retrieve similar training examples for classification"

    # Build index (this creates separate FAISS index for each rule)
    print("\nBuilding rule-filtered indices...")
    retriever.build_index(
        df_train_vs,
        rule_col='rule',
        comment_col='body',
        value_col='value',
        instruction=instruction
    )

    print("\n✓ Index building complete!")


    # Load test data & predict

    # Batch retrieval with reranking
    print(f"\nEvaluating with retrieval_k={RETRIEVAL_K}, rerank_top_k={RERANK_TOP_K}...")

    results_df = retriever.batch_retrieve(
        df_test,
        rule_col='rule',
        comment_col='body',
        top_k=RERANK_TOP_K,
        retrieval_k=RETRIEVAL_K,
        instruction=instruction,
        use_reranking=USE_VLLM_RERANKER,
        faiss_weight= 0.999,
        rerank_weight= 0.001
    )

    # Calculate metrics
    y_true = df_test["rule_violation"]
    y_pred = results_df["decision"].values
    f1 = f1_score(y_true, y_pred)
    print(f"  F1-Score: {f1:.4f}")
    print("num_retrieved unique:", results_df["num_retrieved"].unique())
    print(f"  Rule match types:")
    print(results_df['rule_match_type'].value_counts().to_string())
    print(f"  Reranked:")
    print(results_df['reranked'].value_counts().to_string())
    print("\n✓ Batch evaluation complete!")


    df_test["rule_violation"]=results_df["decision"].values
    df_test[["row_id","rule_violation"]].to_csv("submission.csv",index=False)
    print(df_test[["row_id","rule_violation"]].head(2))
    print(results_df.head(5))
# Out:
# Overwriting run_similarity_search.py

# %%
# !python load_train_test_data.py
# Out:
# Total training examples: 2,029
# Unique rules: 2
#
# Columns: ['row_id', 'body', 'rule', 'subreddit', 'positive_example_1', 'positive_example_2', 'negative_example_1', 'negative_example_2', 'rule_violation', 'value']
#
# Rule distribution statistics:
#   Mean examples per rule: 1014.5
#   Median examples per rule: 1014.5
#   Min examples per rule: 1012
#   Max examples per rule: 1017
# [-1  1]
# (10145, 5)
# [-1  1]
#
# Rule distribution statistics:
#   Mean examples per rule: 5072.5
#   Median examples per rule: 5072.5
#   Min examples per rule: 5060
#   Max examples per rule: 5085
#
# Test sample rule distribution statistics:
#   Mean examples per rule: 3.5
#   Median examples per rule: 3.5
#   Min examples per rule: 1
#   Max examples per rule: 6
# [100]
# (7, 10)
# (28, 5)
# [ 1 -1]
# value
#  1    14
# -1    14
# Name: count, dtype: int64
#
# Rule distribution statistics:
#   Mean examples per rule: 14.0
#   Median examples per rule: 14.0
#   Min examples per rule: 4
#   Max examples per rule: 24
#
# Combined train shape (train + 60% test): (10173, 5)
# Applying prompt formatting with subreddit context...
# Cleaning text...
# Final shape: (10173, 6)
# df train vs saved success.!

# %%
# !python run_similarity_search.py
# Out:
# INFO 10-19 23:49:29 [__init__.py:235] Automatically detected platform cuda.
# Preprocessing test data...
# (10173, 4)
# Loading Qwen3-Embedding model with VLLM...
# INFO 10-19 23:49:37 [config.py:538] Found sentence-transformers modules configuration.
# INFO 10-19 23:49:37 [config.py:558] Found pooling configuration.
# WARNING 10-19 23:49:37 [config.py:3443] Casting torch.bfloat16 to torch.float16.
# INFO 10-19 23:49:37 [config.py:1604] Using max model len 3072
# INFO 10-19 23:49:37 [arg_utils.py:1551] (Enabling) chunked prefill by default
# INFO 10-19 23:49:38 [config.py:2434] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 10-19 23:49:39 [__init__.py:2899] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reason: CUDA is initialized
# INFO 10-19 23:49:43 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-19 23:49:44 [core.py:572] Waiting for init message from front-end.
# INFO 10-19 23:49:44 [core.py:71] Initializing a V1 LLM engine (v0.10.0) with config: model='Qwen/Qwen3-Embedding-0.6B', speculative_config=None, tokenizer='Qwen/Qwen3-Embedding-0.6B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=3072, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=Qwen/Qwen3-Embedding-0.6B, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=False, pooler_config=PoolerConfig(pooling_type='LAST', normalize=True, softmax=None, step_tag_id=None, returned_token_ids=None), compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"max_capture_size":512,"local_cache_dir":null}
# INFO 10-19 23:49:45 [parallel_state.py:1102] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# WARNING 10-19 23:49:45 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# INFO 10-19 23:49:45 [gpu_model_runner.py:1843] Starting to load model Qwen/Qwen3-Embedding-0.6B...
# INFO 10-19 23:49:45 [gpu_model_runner.py:1875] Loading model from scratch...
# INFO 10-19 23:49:45 [cuda.py:290] Using Flash Attention backend on V1 engine.
# INFO 10-19 23:49:46 [weight_utils.py:296] Using model weights format ['*.safetensors']
# INFO 10-19 23:49:46 [weight_utils.py:349] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  3.37it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  3.37it/s]
#
# INFO 10-19 23:49:47 [default_loader.py:262] Loading weights took 0.32 seconds
# INFO 10-19 23:49:47 [gpu_model_runner.py:1892] Model loading took 1.1177 GiB and 1.674921 seconds
# INFO 10-19 23:49:54 [backends.py:530] Using cache directory: /home/vino/.cache/vllm/torch_compile_cache/d378339548/rank_0_0/backbone for vLLM's torch.compile
# INFO 10-19 23:49:54 [backends.py:541] Dynamo bytecode transform time: 6.56 s
# INFO 10-19 23:49:59 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 4.539 s
# INFO 10-19 23:49:59 [monitor.py:34] torch.compile takes 6.56 s in total
# INFO 10-19 23:50:00 [gpu_worker.py:255] Available KV cache memory: 3.34 GiB
# INFO 10-19 23:50:00 [kv_cache_utils.py:833] GPU KV cache size: 31,248 tokens
# INFO 10-19 23:50:00 [kv_cache_utils.py:837] Maximum concurrency for 3,072 tokens per request: 10.17x
# Capturing CUDA graph shapes: 100%|██████████████| 67/67 [00:01<00:00, 42.64it/s]
# INFO 10-19 23:50:02 [gpu_model_runner.py:2485] Graph capturing finished in 2 secs, took 0.47 GiB
# INFO 10-19 23:50:02 [core.py:193] init engine (profile, create kv cache, warmup model) took 14.88 seconds
# Embedder initialized on device: cuda
#
# Loading Qwen3-Reranker model with VLLM...
# WARNING 10-19 23:50:06 [config.py:3443] Casting torch.bfloat16 to torch.float16.
# INFO 10-19 23:50:06 [config.py:1604] Using max model len 3072
# INFO 10-19 23:50:06 [arg_utils.py:1551] (Disabling) chunked prefill by default
# INFO 10-19 23:50:06 [config.py:4628] Only "last" pooling supports chunked prefill and prefix caching; disabling both.
# INFO 10-19 23:50:11 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-19 23:50:12 [core.py:572] Waiting for init message from front-end.
# INFO 10-19 23:50:12 [core.py:71] Initializing a V1 LLM engine (v0.10.0) with config: model='Qwen/Qwen3-Reranker-0.6B', speculative_config=None, tokenizer='Qwen/Qwen3-Reranker-0.6B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=3072, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=Qwen/Qwen3-Reranker-0.6B, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=False, chunked_prefill_enabled=False, use_async_output_proc=False, pooler_config=PoolerConfig(pooling_type=None, normalize=None, softmax=None, step_tag_id=None, returned_token_ids=None), compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"max_capture_size":512,"local_cache_dir":null}
# INFO 10-19 23:50:13 [parallel_state.py:1102] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# WARNING 10-19 23:50:13 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# INFO 10-19 23:50:13 [gpu_model_runner.py:1843] Starting to load model Qwen/Qwen3-Reranker-0.6B...
# INFO 10-19 23:50:13 [gpu_model_runner.py:1875] Loading model from scratch...
# INFO 10-19 23:50:13 [cuda.py:290] Using Flash Attention backend on V1 engine.
# INFO 10-19 23:50:14 [weight_utils.py:296] Using model weights format ['*.safetensors']
# INFO 10-19 23:50:15 [weight_utils.py:349] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  3.15it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  3.15it/s]
#
# INFO 10-19 23:50:15 [default_loader.py:262] Loading weights took 0.34 seconds
# INFO 10-19 23:50:15 [gpu_model_runner.py:1892] Model loading took 1.1196 GiB and 1.612051 seconds
# INFO 10-19 23:50:22 [backends.py:530] Using cache directory: /home/vino/.cache/vllm/torch_compile_cache/4baf4599f0/rank_0_0/backbone for vLLM's torch.compile
# INFO 10-19 23:50:22 [backends.py:541] Dynamo bytecode transform time: 6.44 s
# INFO 10-19 23:50:26 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 4.271 s
# INFO 10-19 23:50:27 [monitor.py:34] torch.compile takes 6.44 s in total
# INFO 10-19 23:50:28 [gpu_worker.py:255] Available KV cache memory: 3.48 GiB
# INFO 10-19 23:50:28 [kv_cache_utils.py:833] GPU KV cache size: 32,608 tokens
# INFO 10-19 23:50:28 [kv_cache_utils.py:837] Maximum concurrency for 3,072 tokens per request: 10.61x
# Capturing CUDA graph shapes: 100%|██████████████| 67/67 [00:01<00:00, 44.47it/s]
# INFO 10-19 23:50:30 [gpu_model_runner.py:2485] Graph capturing finished in 2 secs, took 0.48 GiB
# INFO 10-19 23:50:30 [core.py:193] init engine (profile, create kv cache, warmup model) took 14.40 seconds
# INFO 10-19 23:50:31 [config.py:4628] Only "last" pooling supports chunked prefill and prefix caching; disabling both.
# Reranker (VLLM) initialized on device: cuda
# Initializing retriever with reranker...
#
# Building rule-filtered indices...
# Building rule-filtered index from 10173 examples...
# Strategy: Filter by rule FIRST, then search by COMMENT similarity only
# Found 2 unique rules
# Encoding comments only (not combined with rules)...
# Adding requests: 100%|██████████████████| 10173/10173 [00:02<00:00, 4758.39it/s]
# Processed prompts: 100%|█| 10173/10173 [00:05<00:00, 1726.11it/s, est. speed inp
# Building per-rule FAISS indices...
#   Rule 'No Advertising: Spam, referral links, unsolicited ...' : 5084 examples
#   Rule 'No legal advice: Do not offer or request legal adv...' : 5089 examples
#
# Index building complete!
# Total rules: 2
# Total examples: 10173
#
# ✓ Index building complete!
#
# Evaluating with retrieval_k=100, rerank_top_k=4...
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3151.24it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 157.66it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6523.93it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1886.58it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3211.57it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 233.91it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7481.63it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2134.27it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3318.28it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 240.73it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5505.77it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1476.24it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3480.75it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 245.38it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8199.93it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2677.27it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3015.32it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 232.33it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6665.69it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1879.20it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3474.98it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 244.89it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6340.93it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1590.37it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3501.09it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 249.94it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8385.29it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2844.72it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3721.65it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 243.16it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8239.00it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2612.81it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2183.40it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 224.21it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5454.16it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1428.15it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3026.19it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 226.65it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6633.23it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1836.89it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2380.42it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 224.44it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5293.06it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1284.89it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3518.71it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 248.85it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8510.96it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2847.44it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3615.78it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 250.21it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8653.17it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2918.63it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2816.86it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 230.28it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6211.32it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1691.91it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3788.89it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 249.19it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8009.54it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2513.26it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2764.87it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 244.47it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6912.71it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1850.13it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2788.77it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 240.04it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6557.05it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1851.69it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2711.25it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 230.41it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5279.40it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1258.54it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2263.52it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 221.90it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6089.27it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1586.13it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3463.50it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 227.64it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7337.40it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1895.17it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3718.35it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 250.60it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8955.37it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2938.00it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3179.91it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 238.19it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6628.66it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1865.39it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2798.07it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 243.06it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5000.82it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1513.25it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3527.59it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 246.19it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6520.21it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1969.42it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2859.10it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 244.47it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6681.67it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1497.16it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2725.34it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 247.03it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6444.24it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1535.57it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2886.65it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 248.99it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6772.04it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1471.46it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 1752.74it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 217.77it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4646.99it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2076.24it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2707.75it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 204.78it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5433.11it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1246.00it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 1915.21it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 217.82it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5780.19it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1484.61it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3211.57it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 250.93it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6400.13it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1687.65it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2597.09it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 240.10it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5637.28it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1336.47it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3088.59it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 244.25it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6020.30it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1513.05it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3264.05it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 246.49it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8177.93it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2754.96it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3509.88it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 246.29it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7567.16it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2005.97it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2857.16it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 233.61it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7511.48it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2206.22it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2600.31it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 215.41it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5940.02it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1397.75it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2718.28it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 245.86it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6037.55it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1347.76it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2902.63it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 232.31it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6203.77it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1625.75it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3393.45it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 239.59it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8076.89it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2439.34it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3418.34it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 240.83it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6643.84it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1505.76it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2445.66it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 226.33it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5436.03it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1227.24it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3524.63it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 244.11it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8445.97it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2634.25it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3792.32it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 245.61it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7532.71it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2189.54it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2811.20it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 241.51it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5181.95it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1205.61it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2499.59it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 227.21it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5094.15it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1107.60it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3201.76it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 233.89it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6211.69it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1681.62it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2626.36it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 221.43it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5702.70it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1450.47it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3284.50it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 227.78it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5744.53it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1418.99it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2396.75it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 221.55it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4957.34it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1278.63it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2511.56it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 225.65it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5987.71it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1522.19it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3469.23it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 245.68it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6095.23it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1423.02it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2574.77it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 233.35it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5632.03it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1466.67it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3039.35it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 230.10it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6716.10it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1862.58it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2574.77it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 242.78it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6042.80it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1409.83it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2955.82it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 239.47it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7006.69it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1936.65it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3243.85it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 236.02it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6812.11it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 430.81it/s, est. speed input: 0
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2998.07it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 237.11it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5992.12it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1491.10it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2792.48it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 242.74it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6773.88it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2057.58it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2953.74it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 239.56it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6657.73it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1725.81it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2770.35it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 236.71it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6061.83it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1497.48it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3134.76it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 243.46it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6210.32it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1745.26it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3609.56it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 241.73it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7923.85it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2681.36it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3116.12it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 241.79it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6237.48it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1689.13it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2152.03it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 221.99it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 3734.35it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1397.41it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3480.75it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 250.05it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5126.27it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2481.18it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2803.68it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 243.67it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 3423.89it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1254.70it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3360.82it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 250.45it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4201.79it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1787.18it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2242.94it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 234.67it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 3744.72it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1402.49it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3199.32it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 241.57it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4393.67it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1766.03it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2581.11it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 232.31it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 3714.08it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1410.11it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3379.78it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 247.23it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4609.53it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2025.43it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3307.81it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 250.81it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 3835.41it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1491.07it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2526.69it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 230.14it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 3696.84it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1418.67it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3274.24it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 245.28it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 3741.11it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1432.04it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3429.52it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 248.96it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5179.67it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2472.93it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3718.35it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 242.78it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5439.24it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2838.34it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3663.15it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 239.32it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4693.59it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2070.97it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3358.13it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 245.38it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5256.09it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2469.34it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3281.93it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 226.30it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6112.47it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2230.27it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3165.51it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 237.54it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7241.32it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2217.80it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2718.28it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 240.13it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7180.20it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2400.38it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2685.21it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 222.01it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6745.83it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1640.42it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3396.20it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 246.62it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6419.14it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1784.05it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2623.08it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 226.00it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5681.05it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1396.93it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2966.27it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 223.41it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5650.97it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1364.05it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2690.38it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 251.93it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6929.33it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1877.53it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3276.80it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 245.94it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6204.32it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1578.10it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3410.00it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 247.07it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6241.34it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1615.68it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2475.98it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 225.86it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5347.45it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1200.65it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2585.88it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 225.89it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5209.80it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1598.09it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2642.91it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 233.63it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5400.83it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1845.29it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2976.79it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 245.57it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5387.98it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1420.52it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3184.74it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 239.98it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6705.15it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1624.20it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2853.27it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 239.98it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5562.15it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1385.06it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3179.91it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 243.71it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7302.99it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2052.09it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2978.91it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 243.50it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6127.32it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1787.45it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3297.41it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 237.56it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8509.60it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2760.29it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2474.52it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 246.99it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5855.62it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1426.25it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2878.73it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 237.09it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6412.92it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1531.37it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3498.17it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 252.12it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8558.42it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2930.38it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2962.08it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 242.56it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7172.91it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2176.37it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3158.36it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 246.71it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7469.49it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2155.15it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2918.79it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 241.26it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6141.45it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1542.55it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3650.40it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 254.00it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 9070.61it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2935.50it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3401.71it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 240.66it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6693.81it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1812.78it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3253.92it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 237.07it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7566.21it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2210.53it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3116.12it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 242.66it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5161.81it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1581.87it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3228.87it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 251.93it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5592.55it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1883.82it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3179.91it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 235.05it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6728.58it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2866.80it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2126.93it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 209.93it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4606.67it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1128.51it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3578.76it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 226.36it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6384.22it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2633.07it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2890.63it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 212.90it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6541.96it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1941.46it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2993.79it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 246.22it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6106.57it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2063.61it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2857.16it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 238.49it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5104.65it/s]
# ...
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1745.58it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2902.63it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 237.19it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5577.02it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1319.81it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3211.57it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 241.64it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6314.37it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1862.71it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2774.01it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 238.88it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5383.74it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1351.78it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2357.68it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 233.87it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5053.14it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1171.27it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2092.97it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 208.29it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5329.48it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1349.37it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2438.55it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 232.14it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6952.08it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2241.90it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3015.32it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 230.53it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6135.66it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1635.75it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3209.11it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 238.68it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7079.53it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1984.36it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2198.27it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 219.79it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5239.96it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1182.65it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2577.94it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 204.82it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4234.81it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1146.11it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2156.45it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 214.00it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5819.98it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1321.12it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2835.91it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 241.51it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6457.00it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1410.77it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3226.39it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 243.46it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6451.60it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1822.99it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3292.23it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 232.67it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7775.21it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2114.93it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2894.62it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 226.12it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8121.48it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2511.98it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3315.66it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 240.60it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8114.95it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2186.06it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3396.20it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 233.68it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7051.95it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1876.59it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2616.53it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 224.70it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5479.20it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1123.43it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2864.96it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 230.15it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6005.62it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1504.48it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2468.69it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 225.23it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5124.47it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1137.76it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2095.06it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 202.63it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6307.88it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1733.21it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2826.35it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 224.39it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7430.71it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2199.69it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2964.17it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 230.77it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7264.92it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2295.43it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2839.75it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 228.70it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5790.23it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1505.82it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3137.10it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 228.32it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6874.12it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1905.84it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2621.44it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 155.37it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4152.45it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1127.78it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3851.52it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 238.94it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8081.82it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2787.11it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2090.88it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 166.77it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5861.13it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1163.53it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3002.37it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 230.22it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6967.17it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1971.15it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2352.39it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 208.02it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5972.77it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1596.08it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2922.86it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 232.33it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6642.70it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1875.95it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2172.09it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 216.42it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5339.49it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1242.79it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2002.05it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 209.21it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5671.24it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1296.66it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 1013.61it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 163.70it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5204.23it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1164.87it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 1770.50it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 218.49it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5825.98it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1369.13it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2057.04it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 232.78it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5172.15it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1064.60it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2945.44it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 226.93it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7520.68it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2080.94it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3495.25it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 237.69it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 8152.27it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2503.46it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3146.51it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 227.48it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5735.28it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1417.19it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 3223.91it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 227.44it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 7312.07it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 2154.98it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2716.52it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 223.72it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6062.43it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1534.02it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2692.11it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 237.95it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 4687.51it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 950.81it/s, est. speed input: 0
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2853.27it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 235.36it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 6291.30it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1381.91it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 2368.33it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 222.60it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 3459.06it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1350.15it/s, est. speed input:
# Adding requests: 100%|██████████████████████████| 1/1 [00:00<00:00, 1251.28it/s]
# Processed prompts: 100%|█| 1/1 [00:00<00:00, 188.03it/s, est. speed input: 0.00
# Adding requests: 100%|██████████████████████| 101/101 [00:00<00:00, 5283.22it/s]
# Processed prompts: 100%|█| 101/101 [00:00<00:00, 1191.66it/s, est. speed input:
#   F1-Score: 0.9017
# num_retrieved unique: [4]
#   Rule match types:
# rule_match_type
# exact    2029
#   Reranked:
# reranked
# True    2029
#
# ✓ Batch evaluation complete!
#    row_id  rule_violation
# 0       0               0
# 1       1               0
#    row_id  rule_violation  decision  ... rule_match_type num_retrieved  reranked
# 0       0       -3.148652         0  ...           exact             4      True
# 1       1       -3.508494         0  ...           exact             4      True
# 2       2        1.601981         1  ...           exact             4      True
# 3       3        3.662211         1  ...           exact             4      True
# 4       4        3.608559         1  ...           exact             4      True
#
# [5 rows x 7 columns]
# [rank0]:[W1019 23:53:39.301024531 ProcessGroupNCCL.cpp:1479] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
# [rank0]:[W1019 23:53:40.473792734 ProcessGroupNCCL.cpp:1479] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
